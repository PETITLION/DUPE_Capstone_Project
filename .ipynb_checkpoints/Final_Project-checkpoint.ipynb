# %% [markdown]
# ### $$ Analystes :\;\;\;\;\;\;\;\;\;\;\; Jeff \; Lwear \; DUVERSEAU \;et \;Lionel \;PETIOTE$$

# %% [markdown]
# # Project Tittle : ***$$\ \ $$***

# %% [markdown]
# # 1. Overview

# %% [markdown]
# ## 1.1. Business Understanding

# %% [markdown]
#  ## 1.2. Objectifs

# %% [markdown]
# ## 2. Importations

# %%
# Ici, sont importées les bibliothèques de base, les autres plus spécialisées seront importées tout au long du notebook.

# Manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Data Importation
df_serial = pd.read_csv("IDXDataset_gdc01.csv")
df1_serial = pd.read_csv("IDXDataset_gdc02.csv")
df2_serial = pd.read_csv("IDXDataset_gdc03.csv")
df3_serial = pd.read_csv("IDXDataset_wpc.csv")

# %%
df_serial.shape
# Out:
# (350000, 8)

# %%
df1_serial.shape
# Out:
# (350000, 8)

# %%
df2_serial.shape
# Out:
# (348575, 8)

# %%
df3_serial.shape
# Out:
# (318242, 7)

# %%
df_serial.columns
# Out:
# Index(['Unnamed: 0', 'SEQ', 'Trans_Calendar_Date', 'Local_Transaction_Time',
#        'CD_TYPE', 'dollar_amt', 'CTR', 'CASE_ID'],
#       dtype='object')

# %%
df1_serial.columns
# Out:
# Index(['Unnamed: 0', 'SEQ', 'Trans_Calendar_Date', 'Local_Transaction_Time',
#        'CD_TYPE', 'dollar_amt', 'CTR', 'CASE_ID'],
#       dtype='object')

# %%
df2_serial.columns
# Out:
# Index(['Unnamed: 0', 'SEQ', 'Trans_Calendar_Date', 'Local_Transaction_Time',
#        'CD_TYPE', 'dollar_amt', 'CTR', 'CASE_ID'],
#       dtype='object')

# %%
df3_serial.columns
# Out:
# Index(['SEQ', 'Trans_Calendar_Date', 'Local_Transaction_Time', 'CASE_ID',
#        'WP_YN', 'CD_TYPE', 'dollar_amt'],
#       dtype='object')

# %%
df_serial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350000 entries, 0 to 349999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              350000 non-null  int64
#  1   SEQ                     350000 non-null  int64
#  2   Trans_Calendar_Date     350000 non-null  object
#  3   Local_Transaction_Time  350000 non-null  object
#  4   CD_TYPE                 350000 non-null  object
#  5   dollar_amt              350000 non-null  float64
#  6   CTR                     350000 non-null  int64
#  7   CASE_ID                 350000 non-null  int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 21.4+ MB

# %%
df_serial.head(50)
# Out:
#     Unnamed: 0  SEQ Trans_Calendar_Date Local_Transaction_Time CD_TYPE  \
# 0            1   41           24-Mar-18               15:54:06     GDC
# 1            2   40           26-Mar-18               11:06:31     GDC
# 2            3   39           27-Mar-18               13:03:02     GDC
# 3            4   38            4-Apr-18               13:35:02     GDC
# 4            5   37            4-Apr-18               18:53:21     GDC
# 5            6   36           13-Apr-18               11:05:41     GDC
# 6            7   35           18-Apr-18               17:35:21     GDC
# 7            8   34           19-Apr-18               15:54:01     GDC
# 8            9   33           24-Apr-18               12:43:54     GDC
# 9           10   32           26-Apr-18               13:53:49     GDC
# 10          11   31           27-Apr-18               11:57:14     GDC
# 11          12   30            2-May-18               16:48:49     GDC
# ...

# %%
Sample = df_serial.head(50)

# %%
#Sample.to_csv('samplecreditcard.csv', index=False)
